# %%
import sympy as sym
import numpy as np
sym.init_printing()
from IPython.display import display,Math
from sympy.abc import x,y
import math
from math import gcd
x,y = sym.symbols('x,y')
import matplotlib.pyplot as plt
import sympy.plotting.plot as symplot
x,a = sym.symbols('x,a')
from matplotlib.patches import Polygon
from matplotlib import pyplot as plt
import cmath as cm
import scipy as sp

# %%
n = 5

for k in range(0,n):
    root = np.exp(2*np.pi*1j*k/n)
    print(root)
# Out:
# (1+0j)
# (0.30901699437494745+0.9510565162951535j)
# (-0.8090169943749473+0.5877852522924732j)
# (-0.8090169943749475-0.587785252292473j)
# (0.30901699437494723-0.9510565162951536j)

# %%
for k in range(0,n):
    z = np.exp(2*np.pi*1j*k/n)
    print(z**n)
# Out:
# (1+0j)
# (0.9999999999999999-1.1102230246251565e-16j)
# (1-6.661338147750939e-16j)
# (0.9999999999999997-4.440892098500626e-16j)
# (1-1.1102230246251565e-15j)

# %%
for k in range(0,n):
    z = sym.exp(2*sym.pi*sym.I*k/n)
    print(z**n)
# Out:
# 1
# 1
# 1
# 1
# 1

# %%
for k in range(0,n):
    z = sym.exp(2*sym.pi*sym.I*k/n)
    display(Math('%s \\Rightarrow %s' %(sym.latex(z),sym.latex(z**n))))
# Out:
# $\displaystyle 1 \Rightarrow 1$
# $\displaystyle e^{\frac{2 i \pi}{5}} \Rightarrow 1$
# $\displaystyle e^{\frac{4 i \pi}{5}} \Rightarrow 1$
# $\displaystyle e^{- \frac{4 i \pi}{5}} \Rightarrow 1$
# $\displaystyle e^{- \frac{2 i \pi}{5}} \Rightarrow 1$

# %%
n = 17

for k in range(0,n):
    z = sym.exp(2*sym.pi*sym.I*k/n)
    display(Math('%s \\Rightarrow %s' %(sym.latex(z),sym.latex(z**n))))
# Out:
# $\displaystyle 1 \Rightarrow 1$
# $\displaystyle e^{\frac{2 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{\frac{4 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{\frac{6 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{\frac{8 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{\frac{10 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{\frac{12 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{\frac{14 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{\frac{16 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{- \frac{16 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{- \frac{14 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{- \frac{12 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{- \frac{10 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{- \frac{8 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{- \frac{6 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{- \frac{4 i \pi}{17}} \Rightarrow 1$
# $\displaystyle e^{- \frac{2 i \pi}{17}} \Rightarrow 1$

# %%
n = 4

for k in range(0,n):
    z = sym.exp(2*sym.pi*sym.I*k/n)
    display(Math('%s \\Rightarrow %s' %(sym.latex(z),sym.latex(z**n))))
# Out:
# $\displaystyle 1 \Rightarrow 1$
# $\displaystyle i \Rightarrow 1$
# $\displaystyle -1 \Rightarrow 1$
# $\displaystyle - i \Rightarrow 1$

# %%
n = 14

for k in range(0,n):
    z = np.exp(2*np.pi*1j*k/n)
    plt.plot([0,np.real(z)],[0,np.imag(z)])

plt.axis('square')

x = np.linspace(0,2*np.pi,100)
plt.plot(np.cos(x),np.sin(x),color='gray')

plt.show()

# %%
n = 14

for k in range(0,n):
    z = np.exp(2*np.pi*1j*k/n)
    plt.plot([0,np.real(z)],[0,np.imag(z)])

plt.axis('square')

x = np.linspace(0,2*np.pi,100)
plt.plot(np.cos(x),np.sin(x),'--',color='gray')

plt.show()

# %%
n = 7

for k in range(0,n):
    z = np.exp(2*np.pi*1j*k/n)
    plt.plot([0,np.real(z)],[0,np.imag(z)])

plt.axis('square')

x = np.linspace(0,2*np.pi,100)
plt.plot(np.cos(x),np.sin(x),color='gray')

plt.show()

# %% [markdown]
# # Exercise
#
# Ke^k2πi/n

# %%
n = 200

color = np.linspace(0,.9,n)

for k in range(0,n):
    z = k*np.exp(2*np.pi*1j*k/n)
    plt.plot([0,np.real(z)],[0,np.imag(z)],linewidth=2,color=[color[k],.3,color[k]])  

plt.axis('square')

plt.axis('square')
plt.axis('off')

plt.show()
