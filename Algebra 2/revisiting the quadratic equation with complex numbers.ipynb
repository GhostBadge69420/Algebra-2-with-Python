# %%
import sympy as sym
import numpy as np
sym.init_printing()
from IPython.display import display,Math
from sympy.abc import x,y
import math
from math import gcd
x,y = sym.symbols('x,y')
import matplotlib.pyplot as plt
import sympy.plotting.plot as symplot
x,a = sym.symbols('x,a')
from matplotlib.patches import Polygon
from matplotlib import pyplot as plt
import cmath as cm
import scipy as sp

# %%
a = 2
b = 7
c = 5

quadeqP = (-b + np.sqrt(b**2 - 4*a*c)) / (2*a)
quadeqN = (-b - np.sqrt(b**2 - 4*a*c)) / (2*a)

print(quadeqP,quadeqN)
# Out:
# -1.0 -2.5

# %%
a = 3
b = 7
c = 5


quadeqP = (-b + np.sqrt(b**2 - 4*a*c)) / (2*a)
quadeqN = (-b - np.sqrt(b**2 - 4*a*c)) / (2*a)

print(quadeqP,quadeqN)
# Out:
# nan nan
# C:\Users\ghost\AppData\Local\Temp\ipykernel_14860\435587096.py:6: RuntimeWarning: invalid value encountered in sqrt
#   quadeqP = (-b + np.sqrt(b**2 - 4*a*c)) / (2*a)
# C:\Users\ghost\AppData\Local\Temp\ipykernel_14860\435587096.py:7: RuntimeWarning: invalid value encountered in sqrt
#   quadeqN = (-b - np.sqrt(b**2 - 4*a*c)) / (2*a)

# %%
a = 3
b = 7
c = 5

quadeqP = (-b + sp.sqrt(b**2 - 4*a*c)) / (2*a)
quadeqN = (-b - sp.sqrt(b**2 - 4*a*c)) / (2*a)

print(quadeqP,quadeqN)
# Out:
# (-1.1666666666666665+0.5527707983925666j) (-1.1666666666666665-0.5527707983925666j)
# C:\Users\ghost\AppData\Local\Temp\ipykernel_14860\69390031.py:5: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#   quadeqP = (-b + sp.sqrt(b**2 - 4*a*c)) / (2*a)
# C:\Users\ghost\AppData\Local\Temp\ipykernel_14860\69390031.py:6: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#   quadeqN = (-b - sp.sqrt(b**2 - 4*a*c)) / (2*a)

# %%
def quadeq(a,b,c):

    # initialize
    out = sp.zeros(2)

    # compute
    out[0] = (-b - sp.sqrt(b**2 - 4*a*c)) / (2*a)
    out[1] = (-b + sp.sqrt(b**2 - 4*a*c)) / (2*a)

    return out

# %%
a = 1
b = range(-5,6)
c = range(-2,11)

M = np.zeros((len(b),len(c)),dtype=complex)

for i in range(0,len(b)):
    for j in range(0,len(c)):
        M[i,j] = quadeq(a,b[i],c[j])[0]

plt.subplot(1,3,1)
plt.imshow(np.real(M),extent=[c[0],c[-1],b[0],b[-1]])
plt.axis('off')
plt.title('real part')

plt.subplot(1,3,1)
plt.imshow(np.imag(M),extent=[c[0],c[-1],b[0],b[-1]])
plt.xlabel('c')
plt.ylabel('b')
plt.title('imag part')

plt.subplot(1,3,1)
plt.imshow(np.absolute(M),extent=[c[0],c[-1],b[0],b[-1]])
plt.axis('off')
plt.title('magnitude')

plt.show()
# Out:
# C:\Users\ghost\AppData\Local\Temp\ipykernel_14860\4274980389.py:4: DeprecationWarning: scipy.zeros is deprecated and will be removed in SciPy 2.0.0, use numpy.zeros instead
#   out = sp.zeros(2)
# C:\Users\ghost\AppData\Local\Temp\ipykernel_14860\4274980389.py:7: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#   out[0] = (-b - sp.sqrt(b**2 - 4*a*c)) / (2*a)
# C:\Users\ghost\AppData\Local\Temp\ipykernel_14860\4274980389.py:8: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#   out[1] = (-b + sp.sqrt(b**2 - 4*a*c)) / (2*a)
# C:\Users\ghost\AppData\Local\Temp\ipykernel_14860\4274980389.py:7: ComplexWarning: Casting complex values to real discards the imaginary part
#   out[0] = (-b - sp.sqrt(b**2 - 4*a*c)) / (2*a)
# C:\Users\ghost\AppData\Local\Temp\ipykernel_14860\4274980389.py:8: ComplexWarning: Casting complex values to real discards the imaginary part
#   out[1] = (-b + sp.sqrt(b**2 - 4*a*c)) / (2*a)

# %%
fig = plt.subplots(3,figsize=(20,20))
plt.subplot(1,3,1)
plt.imshow(np.real(M), extent=[c[0], c[-1], b[0], b[-1]])
#plt.axis('off')
plt.xlabel('c')
plt.ylabel('b')
plt.colorbar(shrink=.2)
plt.title('real part')
 
plt.subplot(1,3,2)
plt.imshow(np.imag(M), extent=[c[0], c[-1], b[0], b[-1]])
#plt.axis('off')
plt.xlabel('c')
plt.ylabel('b')
plt.colorbar(shrink=.2)
plt.title('imaginary part')
 
plt.subplot(1,3,3)
plt.imshow(np.absolute(M), extent=[c[0], c[-1], b[0], b[-1]])
#plt.axis('off')
plt.xlabel('c')
plt.ylabel('b')
plt.colorbar(shrink=.2)
plt.title('magnitude')
 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ghost\AppData\Local\Temp\ipykernel_14860\1805627738.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,1)
